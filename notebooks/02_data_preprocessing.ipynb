# %% [markdown]
# <a href="https://colab.research.google.com/github/hvnguyyen/255-deep-learning/blob/main/notebooks/02_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print("Preprocessing notebook ready.")
# Out:
# Preprocessing notebook ready.
